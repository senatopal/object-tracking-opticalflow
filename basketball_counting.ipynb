# %%
from ultralytics import YOLO
import cv2
import math
import time

model = YOLO("best.pt")

class_names = {0: 'Basketball', 1: 'Basketball Hoop'}

cap = cv2.VideoCapture("basketball.mp4")

prev_center = None
prev_time = None
basket_count = 0
basket_done = False

while True:
    ret, frame = cap.read()
    if not ret: 
        break
    
    results = model(frame)[0]
    
    basketball_centers = []
    hoop_boxes = []

    for box in results.boxes:
        cls = int(box.cls[0])
        name = class_names.get(cls, f'class_{cls}')
        x1, y1, x2, y2 = map(int, box.xyxy[0])
        
        if name == 'Basketball':
            cx = int((x1 + x2) / 2)
            cy = int((y1 + y2) / 2)
            basketball_centers.append((cx, cy))
            cv2.circle(frame, (cx, cy), 8, (0,0,255), -1)
            cv2.putText(frame, name, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0,0,255), 2)
        
        elif name == 'Basketball Hoop':
            hoop_boxes.append((x1, y1, x2, y2))
            cv2.rectangle(frame, (x1,y1), (x2,y2), (0,255,0), 2)
            cv2.putText(frame, name, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0,255,0), 2)

    if basketball_centers:
        center = basketball_centers[0]
        current_time = time.time()

        if prev_center is not None and prev_time is not None:
            dx = center[0] - prev_center[0]
            dy = center[1] - prev_center[1]
            dist = math.sqrt(dx*dx + dy*dy)
            dt = current_time - prev_time
            
            if dt > 0:
                speed = dist / dt
                cv2.putText(frame, f"Speed: {speed:.2f} px/s", (50,50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255), 2)
        else:
            speed = 0
        
        prev_center = center
        prev_time = current_time

        for (hx1, hy1, hx2, hy2) in hoop_boxes:
            if hx1 < center[0] < hx2 and hy1 < center[1] < hy2:
                if not basket_done:
                    basket_count += 1
                    basket_done = True
                    print(f"Basket made! Total: {basket_count}")
                cv2.putText(frame, "Basket!", (center[0], center[1] - 30), cv2.FONT_HERSHEY_SIMPLEX, 1.2, (0,255,255), 3)
                break
        else:
            basket_done = False

    cv2.putText(frame, f"Total Baskets: {basket_count}", (10, frame.shape[0] - 20), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,0), 2)
    
    cv2.imshow("Basket Detection with Speed", frame)
    if cv2.waitKey(1) & 0xFF == 27:
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 Basketball Hoop, 345.7ms
# Speed: 15.6ms preprocess, 345.7ms inference, 23.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball Hoop, 243.6ms
# Speed: 20.1ms preprocess, 243.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball, 229.1ms
# Speed: 17.3ms preprocess, 229.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball, 285.4ms
# Speed: 0.0ms preprocess, 285.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball, 244.8ms
# Speed: 12.5ms preprocess, 244.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball, 278.3ms
# Speed: 12.7ms preprocess, 278.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball, 254.6ms
# Speed: 0.0ms preprocess, 254.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball, 281.4ms
# Speed: 0.0ms preprocess, 281.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball, 234.3ms
# Speed: 10.7ms preprocess, 234.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball, 334.1ms
# Speed: 3.0ms preprocess, 334.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball, 216.3ms
# Speed: 5.0ms preprocess, 216.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball, 236.4ms
# Speed: 4.5ms preprocess, 236.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball, 228.0ms
# Speed: 8.0ms preprocess, 228.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 245.2ms
# Speed: 0.0ms preprocess, 245.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 207.7ms
# Speed: 6.9ms preprocess, 207.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 231.1ms
# Speed: 5.1ms preprocess, 231.1ms inference, 13.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball Hoop,
2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball Hoop, 192.1ms
# Speed: 5.8ms preprocess, 192.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball Hoop, 173.3ms
# Speed: 0.0ms preprocess, 173.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball Hoop, 153.6ms
# Speed: 5.1ms preprocess, 153.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball Hoop, 161.1ms
# Speed: 8.4ms preprocess, 161.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball Hoop, 175.8ms
# Speed: 0.0ms preprocess, 175.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball Hoop, 244.1ms
# Speed: 0.0ms preprocess, 244.1ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball Hoop, 165.2ms
# Speed: 8.9ms preprocess, 165.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball Hoop, 174.1ms
# Speed: 2.5ms preprocess, 174.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball, 1 Basketball Hoop, 160.3ms
# Speed: 4.6ms preprocess, 160.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball, 1 Basketball Hoop, 181.8ms
# Speed: 0.0ms preprocess, 181.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball, 1 Basketball Hoop, 162.7ms
# Speed: 5.5ms preprocess, 162.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball, 1 Basketball Hoop, 157.1ms
# Speed: 0.0ms preprocess, 157.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball, 1 Basketball Hoop, 225.7ms
# Speed: 8.2ms preprocess, 225.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball, 1 Basketball Hoop, 147.0ms
# Speed: 6.6ms preprocess, 147.0ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball, 1 Basketball Hoop, 166.3ms
# Speed: 7.2ms preprocess, 166.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball, 1 Basketball Hoop, 163.7ms
# Speed: 0.0ms preprocess, 163.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball, 1 Basketball Hoop, 167.2ms
# Speed: 8.8ms preprocess, 167.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball, 1 Basketball Hoop, 151.4ms
# Speed: 5.0ms preprocess, 151.4ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball, 1 Basketball Hoop, 244.8ms
# Speed: 0.0ms preprocess, 244.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball, 1 Basketball Hoop, 165.2ms
# Speed: 0.0ms preprocess, 165.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Basket made! Total: 5
#
# 0: 384x640 1 Basketball, 2 Basketball Hoops, 184.8ms
# Speed: 0.0ms preprocess, 184.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Basketball Hoops, 168.8ms
# Speed: 2.5ms preprocess, 168.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball, 2 Basketball Hoops, 150.9ms
# Speed: 0.0ms preprocess, 150.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball, 1 Basketball Hoop, 168.0ms
# Speed: 0.0ms preprocess, 168.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball, 1 Basketball Hoop, 246.3ms
# Speed: 0.0ms preprocess, 246.3ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball, 1 Basketball Hoop, 171.8ms
# Speed: 0.0ms preprocess, 171.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball, 1 Basketball Hoop, 150.0ms
# Speed: 3.5ms preprocess, 150.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball, 1 Basketball Hoop, 175.6ms
# Speed: 1.5ms preprocess, 175.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball, 1 Basketball Hoop, 173.4ms
# Speed: 0.0ms preprocess, 173.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball Hoop, 167.8ms
# Speed: 0.0ms preprocess, 167.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball Hoop, 231.0ms
# Speed: 8.0ms preprocess, 231.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball Hoop, 174.4ms
# Speed: 3.7ms preprocess, 174.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball Hoop, 161.4ms
# Speed: 4.5ms preprocess, 161.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball Hoop, 174.6ms
# Speed: 6.4ms preprocess, 174.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball Hoop, 166.1ms
# Speed: 9.5ms preprocess, 166.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball Hoop, 176.4ms
# Speed: 0.0ms preprocess, 176.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball Hoop, 250.3ms
# Speed: 0.0ms preprocess, 250.3ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball, 1 Basketball Hoop, 163.9ms
# Speed: 8.0ms preprocess, 163.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball Hoop, 163.5ms
# Speed: 8.3ms preprocess, 163.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball Hoop, 157.6ms
# Speed: 0.0ms preprocess, 157.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball Hoop, 167.5ms
# Speed: 0.0ms preprocess, 167.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball Hoop, 157.1ms
# Speed: 0.0ms preprocess, 157.1ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball Hoop, 231.7ms
# Speed: 0.0ms preprocess, 231.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball Hoop, 164.5ms
# Speed: 0.0ms preprocess, 164.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball Hoop, 168.3ms
# Speed: 0.0ms preprocess, 168.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball Hoop, 167.2ms
# Speed: 9.0ms preprocess, 167.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball, 1 Basketball Hoop, 172.8ms
# Speed: 1.5ms preprocess, 172.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball Hoop, 159.1ms
# Speed: 5.5ms preprocess, 159.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Basketball Hoop, 239.4ms
# Speed: 0.0ms preprocess, 239.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
